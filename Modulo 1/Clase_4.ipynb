# %%
# %matplotlib notebook
from sympy import *
import numpy as np
import matplotlib.pyplot as plt
init_printing()

# %%
var("x y t")
# Out:
# (x, y, t)

# %%
f=x**3 - 3*x**2 - 24*x + 32
plot(f)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f=x**3 - 3*x**2 - 24*x + 32
df= f.diff()
ddf= df.diff()
df,ddf
# Out:
# ⎛   2                    ⎞
# ⎝3⋅x  - 6⋅x - 24, 6⋅x - 6⎠

# %%
pc = solve(df)
pc
# Out:
# [-2, 4]

# %%
ddf.subs(x,pc[0]),ddf.subs(x,pc[1])
# Out:
# (-18, 18)

# %%
var("x y")
# Out:
# (x, y)

# %%
Eql = Eq (2*x+ y)
Eql=2400
Y = 2400 - 2*X
A = X*(2400 - 2*X)
A = 2400*X -2*X**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-69aa3e0fbfe6> in <module>()
#       1 Eql = Eq (2*x+ y)
#       2 Eql=2400
# ----> 3 Y = 2400 - 2*X
#       4 A = X*(2400 - 2*X)
#       5 A = 2400*X -2*X**2
#
# NameError: name 'X' is not defined

# %%
A= x*y
eql= Eq(2*x+y,2400)
A, eql
# Out:
# (x⋅y, 2⋅x + y = 2400)

# %%
y_=solve(eql,y)
y_
# Out:
# [-2⋅x + 2400]

# %%
f= A.subs(y,y_[0])
f
# Out:
# x⋅(-2⋅x + 2400)

# %%
df= f.diff()
ddf=f.diff()

# %%
pc=solve(df)
pc
# Out:
# [600]

# %%
eql.subs(x,600)
# Out:
# y + 1200 = 2400

# %%
solve(eql.subs(x,600),y)
# Out:
# [1200]
